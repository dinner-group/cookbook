# %% [markdown]
# #Installation

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install rdkit
# Out:
# 2.3.0+cu121
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting rdkit
#   Downloading rdkit-2023.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.6

# %% [markdown]
# # PyG Data Structure

# %%
import torch
from tqdm import tqdm
from torch_geometric.data import Data, DataLoader
from torch_geometric.datasets import QM9 # We will use the QM9 dataset for this example

class QM9Transform:
    def __call__(self, data):
        # Select target.
        data.y = data.y[:, 0]
        return data


path = './QM9'

dataset = QM9(path, transform=QM9Transform()).shuffle()

# Normalize targets to mean = 0 and std = 1.
mean = dataset.data.y.mean(dim=0, keepdim=True)
std = dataset.data.y.std(dim=0, keepdim=True)
dataset.data.y = (dataset.data.y - mean) / std
mean, std = mean[:, 0].item(), std[:, 0].item()

# Split datasets.
test_dataset = dataset[:10000]
val_dataset = dataset[10000:20000]
train_dataset = dataset[20000:]
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The given 'InMemoryDataset' only references a subset of examples of the full dataset, but 'data' will contain information of the full dataset. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# QM9(130831)

# %%
# see what is inside
sample_data = dataset[0]
sample_data
# Out:
# Data(x=[17, 11], edge_index=[2, 36], edge_attr=[36, 4], y=[1], pos=[17, 3], idx=[1], name='gdb_81404', z=[17])

# %% [markdown]
# # Build the first GCN

# %%
from torch.nn import Dropout1d
from torch_geometric.nn import GCNConv
from torch_scatter import scatter

# Let's say I want to build a 2-layer GCN with 0.3 dropout and relu activation

class Net(torch.nn.Module):

  def __init__(self,
               input_dim:int=32,
               hidden_dim:int=32,
               output_dim:int=32,
               *args,
               **kwargs) -> None:
     super().__init__(*args, **kwargs)
     
     # fill in the convolutional layers, check the documentation for GCNConv: https://pytorch-geometric.readthedocs.io/en/latest/generated/torch_geometric.nn.conv.GCNConv.html
     # self.conv1 = 
     # self.conv2 = 
     self.dropout = Dropout1d(p=0.3)
     self.activation = torch.nn.ReLU()

     self.input_dim = input_dim

  def forward(self,data):
    x = data.x
    edge_index = data.edge_index

    assert x.size(-1) == self.input_dim

    # x = 
    x = self.activation(x)
    # x = 
    x = self.dropout(x)
    # graph level readout, check the documentation for scatter: https://pytorch-scatter.readthedocs.io/en/latest/functions/scatter.html
    # x = 

    return x

# %%
# test our sample network
sample_data.batch = torch.zeros(sample_data.pos.size(0)).long()
model = Net(11,64,1)
model(sample_data)
# Out:
# tensor([[20.4077]], grad_fn=<ScatterAddBackward0>)

# %% [markdown]
# # Training loop

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = Net(11,64,1).to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                       factor=0.7, patience=5,
                                                       min_lr=0.00001)

# %%
from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

# define the optimizer and loss function
from torch.optim import Adam
from torch.nn import L1Loss

optimizer = Adam(net.parameters(), lr=1e-3)
criterion = L1Loss()

# define the training loop

def train():
    net.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()

        with autocast():
            out = net(data)
            loss = criterion(out.view(-1), data.y.view(-1))

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()

    return total_loss / len(train_loader)

@torch.no_grad()
def test(loader):
    net.eval()

    total_loss = 0
    for data in loader:
        data = data.to(device)
        with autocast():
            out = net(data)
            total_loss += criterion(out.view(-1), data.y.view(-1)).item()

    return total_loss / len(loader)

# %%
best_val_error = None
for epoch in range(1, 21):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train()
    val_error = test(val_loader)
    scheduler.step(val_error)

    if best_val_error is None or val_error <= best_val_error:
        test_error = test(test_loader)
        best_val_error = val_error

    print(f'Epoch: {epoch:03d}, LR: {lr:7f}, Loss: {loss:.7f}, '
          f'Val MAE: {val_error:.7f}, Test MAE: {test_error:.7f}')
# Out:
# Epoch: 001, LR: 0.000500, Loss: 0.8198288, Val MAE: 0.6740510, Test MAE: 0.6729905
# Epoch: 002, LR: 0.000500, Loss: 0.6693683, Val MAE: 0.6442012, Test MAE: 0.6453697
# Epoch: 003, LR: 0.000500, Loss: 0.6556587, Val MAE: 0.6334624, Test MAE: 0.6371701
# Epoch: 004, LR: 0.000500, Loss: 0.6490098, Val MAE: 0.6322935, Test MAE: 0.6353899
# Epoch: 005, LR: 0.000500, Loss: 0.6485257, Val MAE: 0.6197366, Test MAE: 0.6237359
# Epoch: 006, LR: 0.000500, Loss: 0.6407827, Val MAE: 0.6221578, Test MAE: 0.6237359
# Epoch: 007, LR: 0.000500, Loss: 0.6374820, Val MAE: 0.6067372, Test MAE: 0.6110349
# Epoch: 008, LR: 0.000500, Loss: 0.6319617, Val MAE: 0.6083696, Test MAE: 0.6110349
# Epoch: 009, LR: 0.000500, Loss: 0.6333933, Val MAE: 0.6054017, Test MAE: 0.6089518
# Epoch: 010, LR: 0.000500, Loss: 0.6292399, Val MAE: 0.6648393, Test MAE: 0.6089518
# Epoch: 011, LR: 0.000500, Loss: 0.6257595, Val MAE: 0.5955086, Test MAE: 0.5982262
# Epoch: 012, LR: 0.000500, Loss: 0.6271705, Val MAE: 0.6339588, Test MAE: 0.5982262
# Epoch: 013, LR: 0.000500, Loss: 0.6250825, Val MAE: 0.5964970, Test MAE: 0.5982262
# Epoch: 014, LR: 0.000500, Loss: 0.6261719, Val MAE: 0.5939561, Test MAE: 0.5965727
# Epoch: 015, LR: 0.000500, Loss: 0.6242340, Val MAE: 0.6151750, Test MAE: 0.5965727
# Epoch: 016, LR: 0.000500, Loss: 0.6231021, Val MAE: 0.6038955, Test MAE: 0.5965727
# Epoch: 017, LR: 0.000500, Loss: 0.6222085, Val MAE: 0.6292816, Test MAE: 0.5965727
# Epoch: 018, LR: 0.000500, Loss: 0.6229963, Val MAE: 0.5985145, Test MAE: 0.5965727
# Epoch: 019, LR: 0.000500, Loss: 0.6224522, Val MAE: 0.6092022, Test MAE: 0.5965727
# Epoch: 020, LR: 0.000500, Loss: 0.6182463, Val MAE: 0.6274098, Test MAE: 0.5965727

# %% [markdown]
# # Using Positional Encoding from Graph Lap.

# %%
import torch
from tqdm import tqdm
import numpy as np
from torch_geometric.data import Data, DataLoader
from torch_geometric.datasets import QM9
from torch_geometric.utils import (
    get_laplacian,
    to_scipy_sparse_matrix,
)
from typing import Any, Optional


def add_node_attr(
    data: Data,
    value: Any,
    attr_name: Optional[str] = None,
) -> Data:
    if attr_name is None:
        if data.x is not None:
            x = data.x.view(-1, 1) if data.x.dim() == 1 else data.x
            data.x = torch.cat([x, value.to(x.device, x.dtype)], dim=-1)
        else:
            data.x = value
    else:
        data[attr_name] = value

    return data

class QM9Transform:
    def __call__(self, data):
        # Select target.
        data.y = data.y[:, 0]
        return data

num_lap_vecs = 16

class LapTransform:
    def __call__(self,data):

        num_nodes = data.num_nodes
        edge_index, edge_weight = get_laplacian(
        data.edge_index,
        data.edge_weight,
        normalization='sym',
        num_nodes=num_nodes,
    )
        L = to_scipy_sparse_matrix(edge_index, edge_weight, num_nodes)
        # eigen decomposition

        # eig_vals, eig_vecs =

        # sort the eigenvectors by eigenvalues
        
        # eig_vecs = np.real()

        # pe = torch.from_numpy(eig_vecs[:, 1:num_lap_vecs + 1])

        if pe.shape[1] < num_lap_vecs:
          pe = torch.nn.functional.pad(pe, (0, num_lap_vecs - pe.shape[1]), value=float(0))

        data = add_node_attr(data, pe, attr_name='pe')
        return data


path = './QM9_lap'
dataset = QM9(path, transform=QM9Transform(),pre_transform=LapTransform()).shuffle()

# Normalize targets to mean = 0 and std = 1.
mean = dataset.data.y.mean(dim=0, keepdim=True)
std = dataset.data.y.std(dim=0, keepdim=True)
dataset.data.y = (dataset.data.y - mean) / std
mean, std = mean[:, 0].item(), std[:, 0].item()

# Split datasets.
test_dataset = dataset[:10000]
val_dataset = dataset[10000:20000]
train_dataset = dataset[20000:]
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

dataset
# Out:
# Processing...
#
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Processing train dataset:   0%|          | 0/10000 [00:00<?, ?it/s]
# Processing train dataset:   1%|          | 102/10000 [00:00<00:09, 1012.75it/s]
# Processing train dataset:   2%|▏         | 206/10000 [00:00<00:09, 1026.53it/s]
# Processing train dataset:   3%|▎         | 309/10000 [00:00<00:10, 900.39it/s]
# Processing train dataset:   4%|▍         | 401/10000 [00:00<00:11, 839.06it/s]
# Processing train dataset:   5%|▍         | 487/10000 [00:00<00:11, 816.45it/s]
# Processing train dataset:   6%|▌         | 573/10000 [00:00<00:11, 828.81it/s]
# Processing train dataset:   7%|▋         | 657/10000 [00:00<00:11, 827.34it/s]
# Processing train dataset:   7%|▋         | 748/10000 [00:00<00:10, 851.20it/s]
# Processing train dataset:   8%|▊         | 844/10000 [00:00<00:10, 882.93it/s]
# Processing train dataset:   9%|▉         | 936/10000 [00:01<00:10, 892.51it/s]
# Processing train dataset:  10%|█         | 1028/10000 [00:01<00:09, 900.35it/s]
# Processing train dataset:  11%|█         | 1119/10000 [00:01<00:09, 901.41it/s]
# Processing train dataset:  12%|█▏        | 1212/10000 [00:01<00:09, 907.68it/s]
# Processing train dataset:  13%|█▎        | 1303/10000 [00:01<00:09, 890.02it/s]
# Processing train dataset:  14%|█▍        | 1393/10000 [00:01<00:09, 881.69it/s]
# Processing train dataset:  15%|█▍        | 1482/10000 [00:01<00:10, 837.65it/s]
# Processing train dataset:  16%|█▌        | 1567/10000 [00:01<00:10, 827.33it/s]
# Processing train dataset:  17%|█▋        | 1654/10000 [00:01<00:09, 838.24it/s]
# Processing train dataset:  17%|█▋        | 1739/10000 [00:02<00:10, 822.47it/s]
# Processing train dataset:  18%|█▊        | 1822/10000 [00:02<00:10, 812.81it/s]
# Processing train dataset:  19%|█▉        | 1904/10000 [00:02<00:10, 808.99it/s]
# Processing train dataset:  20%|█▉        | 1989/10000 [00:02<00:09, 817.88it/s]
# Processing train dataset:  21%|██        | 2071/10000 [00:02<00:09, 809.20it/s]
# Processing train dataset:  22%|██▏       | 2152/10000 [00:02<00:10, 745.78it/s]
# Processing train dataset:  22%|██▏       | 2229/10000 [00:02<00:10, 751.94it/s]
# Processing train dataset:  23%|██▎       | 2307/10000 [00:02<00:10, 756.58it/s]
# Processing train dataset:  24%|██▍       | 2384/10000 [00:02<00:10, 754.99it/s]
# Processing train dataset:  25%|██▍       | 2465/10000 [00:02<00:09, 770.76it/s]
# Processing train dataset:  25%|██▌       | 2547/10000 [00:03<00:09, 784.59it/s]
# Processing train dataset:  27%|██▋       | 2657/10000 [00:03<00:08, 876.64it/s]
# Processing train dataset:  28%|██▊       | 2766/10000 [00:03<00:07, 939.39it/s]
# Processing train dataset:  29%|██▉       | 2886/10000 [00:03<00:07, 1015.05it/s]
# Processing train dataset:  30%|███       | 3001/10000 [00:03<00:06, 1053.14it/s]
# Processing train dataset:  31%|███       | 3107/10000 [00:03<00:06, 1040.03it/s]
# Processing train dataset:  32%|███▏      | 3213/10000 [00:03<00:06, 1045.65it/s]
# Processing train dataset:  33%|███▎      | 3318/10000 [00:03<00:06, 1045.06it/s]
# Processing train dataset:  34%|███▍      | 3438/10000 [00:03<00:06, 1088.25it/s]
# Processing train dataset:  36%|███▌      | 3553/10000 [00:03<00:05, 1104.66it/s]
# Processing train dataset:  37%|███▋      | 3676/10000 [00:04<00:05, 1141.50it/s]
# Processing train dataset:  38%|███▊      | 3791/10000 [00:04<00:05, 1136.24it/s]
# Processing train dataset:  39%|███▉      | 3913/10000 [00:04<00:05, 1160.05it/s]
# Processing train dataset:  40%|████      | 4037/10000 [00:04<00:05, 1182.93it/s]
# Processing train dataset:  42%|████▏     | 4156/10000 [00:04<00:04, 1173.97it/s]
# Processing train dataset:  43%|████▎     | 4274/10000 [00:04<00:04, 1148.61it/s]
# Processing train dataset:  44%|████▍     | 4390/10000 [00:04<00:04, 1148.23it/s]
# Processing train dataset:  45%|████▌     | 4508/10000 [00:04<00:04, 1156.56it/s]
# Processing train dataset:  46%|████▌     | 4624/10000 [00:04<00:04, 1132.83it/s]
# Processing train dataset:  47%|████▋     | 4742/10000 [00:04<00:04, 1146.25it/s]
# Processing train dataset:  49%|████▊     | 4860/10000 [00:05<00:04, 1154.09it/s]
# Processing train dataset:  50%|████▉     | 4976/10000 [00:05<00:04, 1137.41it/s]
# Processing train dataset:  51%|█████     | 5095/10000 [00:05<00:04, 1150.88it/s]
# Processing train dataset:  52%|█████▏    | 5211/10000 [00:05<00:04, 1126.35it/s]
# Processing train dataset:  53%|█████▎    | 5324/10000 [00:05<00:04, 1117.31it/s]
# Processing train dataset:  54%|█████▍    | 5436/10000 [00:05<00:04, 1076.80it/s]
# Processing train dataset:  55%|█████▌    | 5545/10000 [00:05<00:04, 1080.14it/s]
# Processing train dataset:  57%|█████▋    | 5654/10000 [00:05<00:04, 1074.55it/s]
# Processing train dataset:  58%|█████▊    | 5767/10000 [00:05<00:03, 1088.24it/s]
# Processing train dataset:  59%|█████▉    | 5876/10000 [00:06<00:03, 1083.81it/s]
# Processing train dataset:  60%|█████▉    | 5989/10000 [00:06<00:03, 1095.06it/s]
# Processing train dataset:  61%|██████    | 6107/10000 [00:06<00:03, 1118.52it/s]
# Processing train dataset:  62%|██████▏   | 6225/10000 [00:06<00:03, 1135.43it/s]
# Processing train dataset:  63%|██████▎   | 6340/10000 [00:06<00:03, 1137.52it/s]
# Processing train dataset:  65%|██████▍   | 6456/10000 [00:06<00:03, 1142.34it/s]
# Processing train dataset:  66%|██████▌   | 6571/10000 [00:06<00:03, 1089.50it/s]
# Processing train dataset:  67%|██████▋   | 6684/10000 [00:06<00:03, 1100.22it/s]
# Processing train dataset:  68%|██████▊   | 6798/10000 [00:06<00:02, 1110.34it/s]
# Processing train dataset:  69%|██████▉   | 6918/10000 [00:06<00:02, 1135.02it/s]
# Processing train dataset:  70%|███████   | 7033/10000 [00:07<00:02, 1139.12it/s]
# Processing train dataset:  71%|███████▏  | 7149/10000 [00:07<00:02, 1143.78it/s]
# Processing train dataset:  73%|███████▎  | 7264/10000 [00:07<00:02, 1141.23it/s]
# Processing train dataset:  74%|███████▍  | 7382/10000 [00:07<00:02, 1150.56it/s]
# Processing train dataset:  75%|███████▍  | 7498/10000 [00:07<00:02, 1141.95it/s]
# Processing train dataset:  76%|███████▌  | 7613/10000 [00:07<00:02, 1131.88it/s]
# Processing train dataset:  77%|███████▋  | 7727/10000 [00:07<00:02, 1111.82it/s]
# Processing train dataset:  78%|███████▊  | 7845/10000 [00:07<00:01, 1129.98it/s]
# Processing train dataset:  80%|███████▉  | 7959/10000 [00:07<00:01, 1121.53it/s]
# Processing train dataset:  81%|████████  | 8079/10000 [00:07<00:01, 1143.81it/s]
# Processing train dataset:  82%|████████▏ | 8196/10000 [00:08<00:01, 1151.50it/s]
# Processing train dataset:  83%|████████▎ | 8312/10000 [00:08<00:01, 1150.05it/s]
# Processing train dataset:  84%|████████▍ | 8432/10000 [00:08<00:01, 1162.58it/s]
# Processing train dataset:  86%|████████▌ | 8552/10000 [00:08<00:01, 1173.64it/s]
# Processing train dataset:  87%|████████▋ | 8670/10000 [00:08<00:01, 1157.33it/s]
# Processing train dataset:  88%|████████▊ | 8786/10000 [00:08<00:01, 1150.92it/s]
# Processing train dataset:  89%|████████▉ | 8902/10000 [00:08<00:00, 1122.88it/s]
# Processing train dataset:  90%|█████████ | 9020/10000 [00:08<00:00, 1137.55it/s]
# Processing train dataset:  91%|█████████▏| 9141/10000 [00:08<00:00, 1157.76it/s]
# Processing train dataset:  93%|█████████▎| 9258/10000 [00:08<00:00, 1161.19it/s]
# Processing train dataset:  94%|█████████▍| 9381/10000 [00:09<00:00, 1180.72it/s]
# Processing train dataset:  95%|█████████▌| 9505/10000 [00:09<00:00, 1195.72it/s]
# Processing train dataset:  96%|█████████▋| 9626/10000 [00:09<00:00, 1197.89it/s]
# Processing train dataset:  97%|█████████▋| 9747/10000 [00:09<00:00, 1199.71it/s]
# Processing train dataset:  99%|█████████▊| 9868/10000 [00:09<00:00, 1199.90it/s]
# Processing train dataset: 100%|██████████| 10000/10000 [00:09<00:00, 1040.22it/s]
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing val dataset:   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing val dataset:   0%|          | 1/1000 [00:00<03:24,  4.88it/s]
# Processing val dataset:   6%|▌         | 59/1000 [00:00<00:03, 240.00it/s]
# Processing val dataset:  16%|█▋        | 164/1000 [00:00<00:01, 537.42it/s]
# Processing val dataset:  27%|██▋       | 269/1000 [00:00<00:01, 711.90it/s]
# Processing val dataset:  39%|███▊      | 386/1000 [00:00<00:00, 860.80it/s]
# Processing val dataset:  50%|█████     | 500/1000 [00:00<00:00, 948.06it/s]
# Processing val dataset:  61%|██████▏   | 614/1000 [00:00<00:00, 1008.01it/s]
# Processing val dataset:  73%|███████▎  | 731/1000 [00:00<00:00, 1055.45it/s]
# 100%|█████████▉| 133321/133885 [05:09<00:01, 553.24it/s]
# 100%|█████████▉| 133384/133885 [05:09<00:00, 575.11it/s]
# 100%|█████████▉| 133443/133885 [05:10<00:00, 577.49it/s]
# 100%|█████████▉| 133502/133885 [05:10<00:00, 573.52it/s]
# 100%|█████████▉| 133560/133885 [05:10<00:00, 549.02it/s]
# 100%|█████████▉| 133616/133885 [05:10<00:00, 539.12it/s]
# 100%|█████████▉| 133671/133885 [05:10<00:00, 514.87it/s]
# 100%|█████████▉| 133723/133885 [05:10<00:00, 494.58it/s]
# 100%|█████████▉| 133773/133885 [05:10<00:00, 488.27it/s]
# 100%|██████████| 133885/133885 [05:10<00:00, 430.60it/s]
# Done!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The given 'InMemoryDataset' only references a subset of examples of the full dataset, but 'data' will contain information of the full dataset. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# QM9(130831)

# %%
dataset[0]
# Out:
# Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1], pos=[17, 3], z=[17], smiles='[H]ONC1=C([H])[C@@H](N([H])[H])[C@]([H])(O[H])C1([H])[H]', name='gdb_22348', idx=[1], pe=[17, 16])
# Data(x=[17, 11], edge_index=[2, 34], edge_attr=[34, 4], y=[1], pos=[17, 3], z=[17], smiles='[H]ONC1=C([H])[C@@H](N([H])[H])[C@]([H])(O[H])C1([H])[H]', name='gdb_22348', idx=[1], pe=[17, 16])

# %%
from torch.nn import Dropout1d
from torch_geometric.nn import GCNConv
from torch_scatter import scatter


class Net(torch.nn.Module):

  def __init__(self,
               input_dim:int=32,
               hidden_dim:int=32,
               output_dim:int=32,
               *args,
               **kwargs) -> None:
     super().__init__(*args, **kwargs)

    #  self.conv1 = 
    #  self.conv2 = 
     self.dropout = Dropout1d(p=0.3)
     self.activation = torch.nn.ReLU()


  def forward(self,data):
    x = data.x
    edge_index = data.edge_index
    pe = data.pe

    # how to use the laplacian eigenvectors?

    # after using the lap eigenvectors, let's use the same GCN as before

    return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = Net(11+16,64,1).to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                       factor=0.7, patience=5,
                                                       min_lr=0.00001)

# %%
from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

from torch.optim import Adam
from torch.nn import L1Loss

optimizer = Adam(net.parameters(), lr=1e-3)
criterion = L1Loss()

def train():
    net.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()

        with autocast():
            out = net(data) 
            loss = criterion(out.view(-1), data.y.view(-1))

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()

    return total_loss / len(train_loader)


@torch.no_grad()
def test(loader):
    net.eval()

    total_loss = 0
    for data in loader:
        data = data.to(device)
        with autocast():
            out = net(data)
            total_loss += criterion(out.view(-1), data.y.view(-1)).item()

    return total_loss / len(loader)

# %%
best_val_error = None
for epoch in range(1, 21):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train()
    val_error = test(val_loader)
    scheduler.step(val_error)

    if best_val_error is None or val_error <= best_val_error:
        test_error = test(test_loader)
        best_val_error = val_error

    print(f'Epoch: {epoch:03d}, LR: {lr:7f}, Loss: {loss:.7f}, '
          f'Val MAE: {val_error:.7f}, Test MAE: {test_error:.7f}')
# Out:
# Processing train dataset:   0%|          | 2/10000 [15:16<1273:08:57, 458.43s/it]
# Epoch: 001, LR: 0.000500, Loss: 0.7526540, Val MAE: 0.6402822, Test MAE: 0.6490042
# Epoch: 002, LR: 0.000500, Loss: 0.6609365, Val MAE: 0.6473056, Test MAE: 0.6490042
# Epoch: 003, LR: 0.000500, Loss: 0.6442807, Val MAE: 0.6072533, Test MAE: 0.6155941
# Epoch: 004, LR: 0.000500, Loss: 0.6305100, Val MAE: 0.6085729, Test MAE: 0.6155941
# Epoch: 005, LR: 0.000500, Loss: 0.6231813, Val MAE: 0.6037212, Test MAE: 0.6113447
# Epoch: 006, LR: 0.000500, Loss: 0.6194320, Val MAE: 0.5908112, Test MAE: 0.5980551
# Epoch: 007, LR: 0.000500, Loss: 0.6171259, Val MAE: 0.5849622, Test MAE: 0.5926509
# Epoch: 008, LR: 0.000500, Loss: 0.6109742, Val MAE: 0.6182257, Test MAE: 0.5926509
# Epoch: 009, LR: 0.000500, Loss: 0.6147881, Val MAE: 0.5829086, Test MAE: 0.5892039
# Epoch: 010, LR: 0.000500, Loss: 0.6052363, Val MAE: 0.5831516, Test MAE: 0.5892039
# Epoch: 011, LR: 0.000500, Loss: 0.6067222, Val MAE: 0.5813650, Test MAE: 0.5887707
# Epoch: 012, LR: 0.000500, Loss: 0.6040835, Val MAE: 0.5906744, Test MAE: 0.5887707
# Epoch: 013, LR: 0.000500, Loss: 0.6047704, Val MAE: 0.5744880, Test MAE: 0.5809288
# Epoch: 014, LR: 0.000500, Loss: 0.6033933, Val MAE: 0.5820351, Test MAE: 0.5809288
# Epoch: 015, LR: 0.000500, Loss: 0.6026415, Val MAE: 0.5969908, Test MAE: 0.5809288
# Epoch: 016, LR: 0.000500, Loss: 0.6018132, Val MAE: 0.5922509, Test MAE: 0.5809288
# Epoch: 017, LR: 0.000500, Loss: 0.5987118, Val MAE: 0.5842556, Test MAE: 0.5809288
# Epoch: 018, LR: 0.000500, Loss: 0.6030127, Val MAE: 0.5868389, Test MAE: 0.5809288
# Epoch: 019, LR: 0.000500, Loss: 0.6003463, Val MAE: 0.5751032, Test MAE: 0.5809288
# Epoch: 020, LR: 0.000350, Loss: 0.5989606, Val MAE: 0.5926187, Test MAE: 0.5809288

# %% [markdown]
# # Graph Transformer (GraphTrans-like)

# %%
from torch.nn import Dropout1d
from torch_geometric.nn import GCNConv
from torch_scatter import scatter

# same MP as before

class MP_block(torch.nn.Module):

  def __init__(self,
               input_dim:int=32,
               hidden_dim:int=32,
               output_dim:int=32,
               *args,
               **kwargs) -> None:
     super().__init__(*args, **kwargs)

    #  self.conv1 = 
    #  self.conv2 = 
     self.dropout = Dropout1d(p=0.3)
     self.activation = torch.nn.ReLU()


  def forward(self,data):
    x = data.x
    edge_index = data.edge_index


    return x

from torch_geometric.utils import to_dense_batch

class GraphTrans(torch.nn.Module):

  def __init__(self,
               input_dim:int=32,
               hidden_dim:int=32,
               output_dim:int=32,
               dual_readout = False,
               use_cls = True,
               *args,
               **kwargs) -> None:
     super().__init__(*args, **kwargs)

     self.mp_block = MP_block(input_dim,hidden_dim,output_dim)
    
     # check: https://pytorch.org/docs/stable/generated/torch.nn.TransformerEncoderLayer.html#torch.nn.TransformerEncoderLayer
     from torch.nn import TransformerEncoderLayer,TransformerEncoder

     trans_layer = TransformerEncoderLayer(
         d_model = hidden_dim+16,
         nhead=4,
         dim_feedforward= 2*hidden_dim,
         dropout=0.2,
         activation='relu',
         batch_first=True
     )
     self.encoder = TransformerEncoder(trans_layer,num_layers=4)

     if use_cls:
      # how to use the cls token? As mentioned, CLS token is initialized as a learnable parameter, how to do that?
        
      # self.cls_token = 

     self.use_cls = use_cls


     self.readout = torch.nn.Linear(hidden_dim+16,1)

     self.dual_readout = dual_readout
     
     if dual_readout:
      self.readout = torch.nn.Linear(2*hidden_dim+16,1)


  def forward(self,data):

    x = self.mp_block(data)
    graph_readout = scatter(x,data.batch,reduce='sum',dim=0)

    src, mask = to_dense_batch(x,data.batch)
    pe, _ = to_dense_batch(data.pe,data.batch)

    src = torch.cat([src,pe],dim=-1)

    if self.use_cls:
      cls_token = self.cls_token.expand(src.shape[0], -1, -1)
      src = torch.cat([cls_token, src], dim=1)
      mask = torch.cat([torch.ones(src.shape[0], 1).bool().to(src.device), mask], dim=1)
      output = self.encoder(src, src_key_padding_mask=~mask)
      output = output[:, 0, :]
    else:
      output = self.encoder(src, src_key_padding_mask=~mask)
      output = output.sum(1)


    if not self.dual_readout:
      output = self.readout(output)

    else:
      output = torch.cat([output,graph_readout],dim=-1)
      output = self.readout(output)

    return output

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = GraphTrans(11,64,1,dual_readout=False,use_cls=True).to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                       factor=0.7, patience=5,
                                                       min_lr=0.00001)

# %%
from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

from torch.optim import Adam
from torch.nn import L1Loss

optimizer = Adam(net.parameters(), lr=1e-3)
criterion = L1Loss()


def train():
    net.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()

        with autocast():
            out = net(data) 
            loss = criterion(out.view(-1), data.y.view(-1))

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()

    return total_loss / len(train_loader)

@torch.no_grad()
def test(loader):
    net.eval()

    total_loss = 0
    for data in loader:
        data = data.to(device)
        with autocast():
            out = net(data)
            total_loss += criterion(out.view(-1), data.y.view(-1)).item()

    return total_loss / len(loader)

# %%
best_val_error = None
for epoch in range(1, 21):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train()
    val_error = test(val_loader)
    scheduler.step(val_error)

    if best_val_error is None or val_error <= best_val_error:
        test_error = test(test_loader)
        best_val_error = val_error

    print(f'Epoch: {epoch:03d}, LR: {lr:7f}, Loss: {loss:.7f}, '
          f'Val MAE: {val_error:.7f}, Test MAE: {test_error:.7f}')
# Out:
# Epoch: 001, LR: 0.000500, Loss: 0.5999675, Val MAE: 0.5470448, Test MAE: 0.5565732
# Epoch: 002, LR: 0.000500, Loss: 0.5403858, Val MAE: 0.5616606, Test MAE: 0.5565732
# Epoch: 003, LR: 0.000500, Loss: 0.5231962, Val MAE: 0.5052637, Test MAE: 0.5127802
# Epoch: 004, LR: 0.000500, Loss: 0.5142129, Val MAE: 0.5028469, Test MAE: 0.5076585
# Epoch: 005, LR: 0.000500, Loss: 0.5082970, Val MAE: 0.5061650, Test MAE: 0.5076585
# Epoch: 006, LR: 0.000500, Loss: 0.5041381, Val MAE: 0.4969436, Test MAE: 0.5035305
# Epoch: 007, LR: 0.000500, Loss: 0.4991217, Val MAE: 0.4915266, Test MAE: 0.5007566
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-0f8382169a0c> in <cell line: 2>()
#       2 for epoch in range(1, 21):
#       3     lr = scheduler.optimizer.param_groups[0]['lr']
# ----> 4     loss = train()
#       5     val_error = test(val_loader)
#       6     scheduler.step(val_error)
#
# <ipython-input-104-edee631f325e> in train()
#      26
#      27         scaler.scale(loss).backward()
# ---> 28         scaler.step(optimizer)
#      29         scaler.update()
#      30
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/grad_scaler.py in step(self, optimizer, *args, **kwargs)
#     451         ), "No inf checks were recorded for this optimizer."
#     452
# --> 453         retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     454
#     455         optimizer_state["stage"] = OptState.STEPPED
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/grad_scaler.py in _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     349         retval: Optional[float] = None
#     350         if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 351             retval = optimizer.step(*args, **kwargs)
#     352         return retval
#     353
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     389                             )
#     390
# --> 391                 out = func(*args, **kwargs)
#     392                 self._optimizer_step_code()
#     393
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in step(self, closure)
#     166                 state_steps)
#     167
# --> 168             adam(
#     169                 params_with_grad,
#     170                 grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     316         func = _single_tensor_adam
#     317
# --> 318     func(params,
#     319          grads,
#     320          exp_avgs,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     565             torch._foreach_addcdiv_(device_params, device_exp_avgs, exp_avg_sq_sqrt)
#     566         else:
# --> 567             bias_correction1 = [1 - beta1 ** _get_value(step) for step in device_state_steps]
#     568             bias_correction2 = [1 - beta2 ** _get_value(step) for step in device_state_steps]
#     569
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in <listcomp>(.0)
#     565             torch._foreach_addcdiv_(device_params, device_exp_avgs, exp_avg_sq_sqrt)
#     566         else:
# --> 567             bias_correction1 = [1 - beta1 ** _get_value(step) for step in device_state_steps]
#     568             bias_correction2 = [1 - beta2 ** _get_value(step) for step in device_state_steps]
#     569
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _get_value(x)
#      84 def _get_value(x):
#      85     # item is significantly faster than a cpu tensor in eager mode
# ---> 86     if not torch.jit.is_scripting() and is_compiling():
#      87         return x
#      88     else:
#
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py in is_compiling()
#     849
#     850
# --> 851 def is_compiling() -> bool:
#     852     """
#     853     Indicates whether we are tracing/compiling with torch.compile() or torch.export().
#
# KeyboardInterrupt:

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = GraphTrans(11,64,1,dual_readout=False,use_cls=False).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0005)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                       factor=0.7, patience=5,
                                                       min_lr=0.00001)

# %%
from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

from torch.optim import Adam
from torch.nn import L1Loss

optimizer = Adam(net.parameters(), lr=1e-3)
criterion = L1Loss()


def train():
    net.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()

        with autocast():
            out = net(data) 
            loss = criterion(out.view(-1), data.y.view(-1))

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()

    return total_loss / len(train_loader)


@torch.no_grad()
def test(loader):
    net.eval()

    total_loss = 0
    for data in loader:
        data = data.to(device)
        with autocast():
            out = net(data)
            total_loss += criterion(out.view(-1), data.y.view(-1)).item()

    return total_loss / len(loader)

# %%
best_val_error = None
for epoch in range(1, 21):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train()
    val_error = test(val_loader)
    scheduler.step(val_error)

    if best_val_error is None or val_error <= best_val_error:
        test_error = test(test_loader)
        best_val_error = val_error

    print(f'Epoch: {epoch:03d}, LR: {lr:7f}, Loss: {loss:.7f}, '
          f'Val MAE: {val_error:.7f}, Test MAE: {test_error:.7f}')
# Out:
# Epoch: 001, LR: 0.000500, Loss: 1.1340361, Val MAE: 0.6864532, Test MAE: 0.6947218
# Epoch: 002, LR: 0.000500, Loss: 0.6069056, Val MAE: 0.7233595, Test MAE: 0.6947218
# Epoch: 003, LR: 0.000500, Loss: 0.5744214, Val MAE: 0.5611899, Test MAE: 0.5692674
# Epoch: 004, LR: 0.000500, Loss: 0.5479245, Val MAE: 0.5437525, Test MAE: 0.5498771
# Epoch: 005, LR: 0.000500, Loss: 0.5345107, Val MAE: 0.4998771, Test MAE: 0.5064580
# Epoch: 006, LR: 0.000500, Loss: 0.5245923, Val MAE: 0.5345667, Test MAE: 0.5064580
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-0f8382169a0c> in <cell line: 2>()
#       2 for epoch in range(1, 21):
#       3     lr = scheduler.optimizer.param_groups[0]['lr']
# ----> 4     loss = train()
#       5     val_error = test(val_loader)
#       6     scheduler.step(val_error)
#
# <ipython-input-101-edee631f325e> in train()
#      22
#      23         with autocast():
# ---> 24             out = net(data) # GNN operates on atomic numbers, positions and batch vector which assigns each atom to a specific molecule
#      25             loss = criterion(out.view(-1), data.y.view(-1))
#      26
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# <ipython-input-99-cebb5e6e4a51> in forward(self, data)
#      77     graph_readout = scatter(x,data.batch,reduce='sum',dim=0)
#      78
# ---> 79     src, mask = to_dense_batch(x,data.batch)
#      80     pe, _ = to_dense_batch(data.pe,data.batch)
#      81
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/experimental.py in wrapper(*args, **kwargs)
#     115         def wrapper(*args: Any, **kwargs: Any) -> Any:
#     116             if not is_experimental_mode_enabled('disable_dynamic_shapes'):
# --> 117                 return func(*args, **kwargs)
#     118
#     119             for required_arg in required_args:
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/utils/_to_dense_batch.py in to_dense_batch(x, batch, fill_value, max_num_nodes, batch_size)
#     104         batch_size = int(batch.max()) + 1
#     105
# --> 106     num_nodes = scatter(batch.new_ones(x.size(0)), batch, dim=0,
#     107                         dim_size=batch_size, reduce='sum')
#     108     cum_nodes = cumsum(num_nodes)
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/utils/_scatter.py in scatter(src, index, dim, dim_size, reduce)
#      72         # For "sum" and "mean" reduction, we make use of `scatter_add_`:
#      73         if reduce == 'sum' or reduce == 'add':
# ---> 74             index = broadcast(index, src, dim)
#      75             return src.new_zeros(size).scatter_add_(dim, index, src)
#      76
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/utils/_scatter.py in broadcast(src, ref, dim)
#     178     dim = ref.dim() + dim if dim < 0 else dim
#     179     size = ((1, ) * dim) + (-1, ) + ((1, ) * (ref.dim() - dim - 1))
# --> 180     return src.view(size).expand_as(ref)
#     181
#     182
#
# KeyboardInterrupt:

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = GraphTrans(11,64,1,dual_readout=True).to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                       factor=0.7, patience=5,
                                                       min_lr=0.00001)

# %%
from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

from torch.optim import Adam
from torch.nn import L1Loss

optimizer = Adam(net.parameters(), lr=1e-3)
criterion = L1Loss()


def train():
    net.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()

        with autocast():
            out = net(data) 
            loss = criterion(out.view(-1), data.y.view(-1))

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()

    return total_loss / len(train_loader)

@torch.no_grad()
def test(loader):
    net.eval()

    total_loss = 0
    for data in loader:
        data = data.to(device)
        with autocast():
            out = net(data)
            total_loss += criterion(out.view(-1), data.y.view(-1)).item()

    return total_loss / len(loader)

# %%
best_val_error = None
for epoch in range(1, 21):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train()
    val_error = test(val_loader)
    scheduler.step(val_error)

    if best_val_error is None or val_error <= best_val_error:
        test_error = test(test_loader)
        best_val_error = val_error

    print(f'Epoch: {epoch:03d}, LR: {lr:7f}, Loss: {loss:.7f}, '
          f'Val MAE: {val_error:.7f}, Test MAE: {test_error:.7f}')
# Out:
# Epoch: 001, LR: 0.000500, Loss: 0.6299823, Val MAE: 0.6426990, Test MAE: 0.6500050
# Epoch: 002, LR: 0.000500, Loss: 0.5605375, Val MAE: 0.5628818, Test MAE: 0.5689878
# Epoch: 003, LR: 0.000500, Loss: 0.5406009, Val MAE: 0.5448830, Test MAE: 0.5526573
# Epoch: 004, LR: 0.000500, Loss: 0.5320968, Val MAE: 0.5522172, Test MAE: 0.5526573
# Epoch: 005, LR: 0.000500, Loss: 0.5232036, Val MAE: 0.5250343, Test MAE: 0.5309696
# Epoch: 006, LR: 0.000500, Loss: 0.5166567, Val MAE: 0.5296919, Test MAE: 0.5309696
# Epoch: 007, LR: 0.000500, Loss: 0.5116349, Val MAE: 0.5145550, Test MAE: 0.5228748
# Epoch: 008, LR: 0.000500, Loss: 0.5049468, Val MAE: 0.5504969, Test MAE: 0.5228748
# Epoch: 009, LR: 0.000500, Loss: 0.5034734, Val MAE: 0.5397349, Test MAE: 0.5228748
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-0f8382169a0c> in <cell line: 2>()
#       2 for epoch in range(1, 21):
#       3     lr = scheduler.optimizer.param_groups[0]['lr']
# ----> 4     loss = train()
#       5     val_error = test(val_loader)
#       6     scheduler.step(val_error)
#
# <ipython-input-97-edee631f325e> in train()
#      17
#      18     total_loss = 0
# ---> 19     for data in train_loader:
#      20         data = data.to(device)
#      21         optimizer.zero_grad()
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
# ---> 54         return self.collate_fn(data)
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/loader/dataloader.py in __call__(self, batch)
#      25         elem = batch[0]
#      26         if isinstance(elem, BaseData):
# ---> 27             return Batch.from_data_list(
#      28                 batch,
#      29                 follow_batch=self.follow_batch,
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/batch.py in from_data_list(cls, data_list, follow_batch, exclude_keys)
#      95         Will exclude any keys given in :obj:`exclude_keys`.
#      96         """
# ---> 97         batch, slice_dict, inc_dict = collate(
#      98             cls,
#      99             data_list=data_list,
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#     107
#     108             # Collate attributes into a unified representation:
# --> 109             value, slices, incs = _collate(attr, values, data_list, stores,
#     110                                            increment)
#     111
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in _collate(key, values, data_list, stores, increment)
#     167         slices = cumsum(sizes)
#     168         if increment:
# --> 169             incs = get_incs(key, values, data_list, stores)
#     170             if incs.dim() > 1 or int(incs[-1]) != 0:
#     171                 values = [
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in get_incs(key, values, data_list, stores)
#     327     repeats = [
#     328         data.__inc__(key, value, store)
# --> 329         for value, data, store in zip(values, data_list, stores)
#     330     ]
#     331     if isinstance(repeats[0], Tensor):
#
# KeyboardInterrupt:

# %% [markdown]
# # SchNet (a simple geometrical MP-GNN)

# %%
from torch_geometric.nn import SchNet

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = SchNet(hidden_channels=64, num_filters=64, num_interactions=3).to(device)
print(net)
# Out:
# SchNet(hidden_channels=64, num_filters=64, num_interactions=3, num_gaussians=50, cutoff=10.0)

# %%
from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

# define the optimizer and loss function
from torch.optim import Adam
from torch.nn import L1Loss

optimizer = Adam(net.parameters(), lr=1e-3)
criterion = L1Loss()


def train():
    net.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()

        with autocast():
            out = net(data.z, data.pos, data.batch)
            loss = criterion(out.view(-1), data.y.view(-1))

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()

    return total_loss / len(train_loader)


@torch.no_grad()
def test(loader):
    net.eval()

    total_loss = 0
    for data in loader:
        data = data.to(device)
        with autocast():
            out = net(data.z, data.pos, data.batch)
            total_loss += criterion(out.view(-1), data.y.view(-1)).item()

    return total_loss / len(loader)

# %%
from tqdm import tqdm

best_val_loss = None
for epoch in tqdm(range(1, 101)):
    loss = train()
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

    if epoch % 2 == 0:
        val_loss = test(val_loader)
        print(f'Val Loss: {val_loss:.4f}')

        if best_val_loss is None or val_loss <= best_val_loss:
            best_val_loss = val_loss
            test_loss = test(test_loader)
            print(f'Test Loss: {test_loss:.4f}')
# Out:
#   1%|          | 1/100 [00:23<38:17, 23.21s/it]
# Epoch: 001, Loss: 0.7536
# Epoch: 002, Loss: 0.3695
# Val Loss: 0.3185
#   2%|▏         | 2/100 [00:47<39:01, 23.89s/it]
# Test Loss: 0.3121
#   3%|▎         | 3/100 [01:07<35:59, 22.26s/it]
# Epoch: 003, Loss: 0.3102
# Epoch: 004, Loss: 0.2707
# Val Loss: 0.2359
#   4%|▍         | 4/100 [01:34<38:20, 23.96s/it]
# Test Loss: 0.2318
#   5%|▌         | 5/100 [01:57<37:10, 23.48s/it]
# Epoch: 005, Loss: 0.2368
# Epoch: 006, Loss: 0.2111
# Val Loss: 0.1971
#   6%|▌         | 6/100 [02:21<37:15, 23.78s/it]
# Test Loss: 0.1928
#   6%|▌         | 6/100 [02:25<37:56, 24.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-492b01b2414e> in <cell line: 5>()
#       4 best_val_loss = None
#       5 for epoch in tqdm(range(1, 101)):
# ----> 6     loss = train()
#       7     print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
#       8
#
# <ipython-input-11-41e38ccad7d2> in train()
#      17
#      18     total_loss = 0
# ---> 19     for data in train_loader:
#      20         data = data.to(device)
#      21         optimizer.zero_grad()
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
# ---> 54         return self.collate_fn(data)
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/loader/dataloader.py in __call__(self, batch)
#      25         elem = batch[0]
#      26         if isinstance(elem, BaseData):
# ---> 27             return Batch.from_data_list(
#      28                 batch,
#      29                 follow_batch=self.follow_batch,
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/batch.py in from_data_list(cls, data_list, follow_batch, exclude_keys)
#      95         Will exclude any keys given in :obj:`exclude_keys`.
#      96         """
# ---> 97         batch, slice_dict, inc_dict = collate(
#      98             cls,
#      99             data_list=data_list,
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#     107
#     108             # Collate attributes into a unified representation:
# --> 109             value, slices, incs = _collate(attr, values, data_list, stores,
#     110                                            increment)
#     111
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in _collate(key, values, data_list, stores, increment)
#     167         slices = cumsum(sizes)
#     168         if increment:
# --> 169             incs = get_incs(key, values, data_list, stores)
#     170             if incs.dim() > 1 or int(incs[-1]) != 0:
#     171                 values = [
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in get_incs(key, values, data_list, stores)
#     325 def get_incs(key, values: List[Any], data_list: List[BaseData],
#     326              stores: List[BaseStorage]) -> Tensor:
# --> 327     repeats = [
#     328         data.__inc__(key, value, store)
#     329         for value, data, store in zip(values, data_list, stores)
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/collate.py in <listcomp>(.0)
#     326              stores: List[BaseStorage]) -> Tensor:
#     327     repeats = [
# --> 328         data.__inc__(key, value, store)
#     329         for value, data, store in zip(values, data_list, stores)
#     330     ]
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py in __inc__(self, key, value, *args, **kwargs)
#     660             return int(value.max()) + 1
#     661         elif 'index' in key or key == 'face':
# --> 662             return self.num_nodes
#     663         else:
#     664             return 0
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py in num_nodes(self)
#     614     @property
#     615     def num_nodes(self) -> Optional[int]:
# --> 616         return super().num_nodes
#     617
#     618     @num_nodes.setter
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py in num_nodes(self)
#     184         """
#     185         try:
# --> 186             return sum([v.num_nodes for v in self.node_stores])
#     187         except TypeError:
#     188             return None
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py in <listcomp>(.0)
#     184         """
#     185         try:
# --> 186             return sum([v.num_nodes for v in self.node_stores])
#     187         except TypeError:
#     188             return None
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/storage.py in num_nodes(self)
#     425         for key, value in self.items():
#     426             if isinstance(value, Tensor) and key in N_KEYS:
# --> 427                 cat_dim = self._parent().__cat_dim__(key, value, self)
#     428                 return value.size(cat_dim)
#     429             if isinstance(value, np.ndarray) and key in N_KEYS:
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py in __cat_dim__(self, key, value, *args, **kwargs)
#     647
#     648     def __cat_dim__(self, key: str, value: Any, *args, **kwargs) -> Any:
# --> 649         if is_sparse(value) and ('adj' in key or 'edge_index' in key):
#     650             return (0, 1)
#     651         elif 'index' in key or key == 'face':
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/utils/sparse.py in is_sparse(src)
#     139         src (Any): The input object to be checked.
#     140     """
# --> 141     return is_torch_sparse_tensor(src) or isinstance(src, SparseTensor)
#     142
#     143
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/utils/sparse.py in is_torch_sparse_tensor(src)
#     121     """
#     122     if isinstance(src, Tensor):
# --> 123         if src.layout == torch.sparse_coo:
#     124             return True
#     125         if src.layout == torch.sparse_csr:
#
# KeyboardInterrupt:
